# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/Users/mwilson/Documents/GitHub/insurance/data/Motor vehicle insurance data.csv', sep=';')

# %%
# check basic information about dataset, set missing data to -1

print(df.shape)
print(df.isna().sum())
dff = df.select_dtypes(include=np.number)
print((dff < 0).sum().sum())
df = df.fillna(-1)
# Out:
# (105555, 30)
# ID                          0
# Date_start_contract         0
# Date_last_renewal           0
# Date_next_renewal           0
# Date_birth                  0
# Date_driving_licence        0
# Distribution_channel        0
# Seniority                   0
# Policies_in_force           0
# Max_policies                0
# Max_products                0
# Lapse                       0
# Date_lapse              70408
# Payment                     0
# Premium                     0
# Cost_claims_year            0
# N_claims_year               0
# N_claims_history            0
# R_Claims_history            0
# Type_risk                   0
# Area                        0
# Second_driver               0
# Year_matriculation          0
# Power                       0
# Cylinder_capacity           0
# Value_vehicle               0
# N_doors                     0
# Type_fuel                1764
# Length                  10329
# Weight                      0
# dtype: int64
# 0

# %%
# expect many with cost claims  = 0, and we are right
# distribution very skewed, so cut off top 0.1% to make graph more readable

dfp = df[df['Cost_claims_year'] >0]
print(dfp.shape)
print("Max claim: ", dfp['Cost_claims_year'].max(), "Median claim: ", dfp['Cost_claims_year'].median(),
      "Mean claim: ", dfp['Cost_claims_year'].mean())
dfp = dfp[df['Cost_claims_year'] < df['Cost_claims_year'].quantile(0.999)]
sns.ecdfplot(data=dfp, x='Cost_claims_year') # note the kink near 1000
# Out:
# (19646, 30)
# Max claim:  260853.24 Median claim:  289.435 Mean claim:  825.0402814822355
# /var/folders/b6/p4rp211j58j0rw69zyy9t14c0000gp/T/ipykernel_64554/2832226717.py:8: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfp = dfp[df['Cost_claims_year'] < df['Cost_claims_year'].quantile(0.999)]
# <Axes: xlabel='Cost_claims_year', ylabel='Proportion'>

# %%
dfp2 = dfp[df['Cost_claims_year'] < df['Cost_claims_year'].quantile(0.99)]
sns.histplot(data=dfp2, x='Cost_claims_year', binwidth=100) 
# seems many claim costs are just under 1000, perhaps a payout limit enforced
# Out:
# /var/folders/b6/p4rp211j58j0rw69zyy9t14c0000gp/T/ipykernel_64554/1795234039.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfp2 = dfp[df['Cost_claims_year'] < df['Cost_claims_year'].quantile(0.99)]
# <Axes: xlabel='Cost_claims_year', ylabel='Count'>

# %%
# brief look at high value claims
df['Cost_claims_year'].nlargest(100)
# Out:
# 55159    260853.24
# 63282    236285.18
# 95817    128809.73
# 92967     71968.87
# 44051     59656.65
#            ...
# 76347     12869.29
# 58944     12806.00
# 69246     12592.80
# 57882     12552.26
# 30798     12406.86
# Name: Cost_claims_year, Length: 100, dtype: float64

# %%
# seems to be a difference between policies coming from agents versus brokers

cols = ['Cost_claims_year','N_claims_year','N_claims_history','R_Claims_history','Distribution_channel']
temp = df.loc[:, cols]
temp = temp.groupby('Distribution_channel')
temp.aggregate('mean')
# Out:
#                       Cost_claims_year  N_claims_year  N_claims_history  \
# Distribution_channel
# 0                           134.762863       0.365937          3.169121
# 1                           176.407083       0.429657          2.244343
#
#                       R_Claims_history
# Distribution_channel
# 0                             0.384119
# 1                             0.475133

# %%
# The vehicle types (motorbike, van, car, agricultural vehicle) differ in claim frequency and cost/claim

def f(row):
    return row['Cost_claims_year']/max(1,row['N_claims_year'])
df['Cost/claim_year'] = df.apply(f, axis=1)
cols = ['Cost_claims_year','N_claims_year','N_claims_history','R_Claims_history','Cost/claim_year','Type_risk']
temp = df.loc[:, cols]
temp = temp.groupby('Type_risk')
temp.aggregate('mean')
# Out:
#            Cost_claims_year  N_claims_year  N_claims_history  \
# Type_risk
# 1                 36.351004       0.145378          1.603270
# 2                166.345241       0.567590          3.507796
# 3                165.101086       0.396747          2.768743
# 4                  0.226404       0.001175          0.831962
#
#            R_Claims_history  Cost/claim_year
# Type_risk
# 1                  0.173970        25.648506
# 2                  0.513436        89.510952
# 3                  0.441156        93.694393
# 4                  0.008484         0.226404

# %%
# frequency of vehicle types in dataset

df['Type_risk'].value_counts()
# Out:
# Type_risk
# 3    82990
# 2    13212
# 1     8502
# 4      851
# Name: count, dtype: int64

# %%
# premium distribution by vehicle type

sns.histplot(data=df, x="Premium", hue="Type_risk", palette='viridis_r')
plt.xlim(0, 1000)
plt.show()

# %%
# same thing, separate plots

sns.displot(
        df,
        x="Premium",
        col="Type_risk",
        kind="hist",
        binwidth=3,
        height=3,
        facet_kws=dict(margin_titles=True),
    )
plt.xlim(0, 1000)
plt.show()

# %%
# now look at claim frequency

g = sns.FacetGrid(df, col="Type_risk", hue="Type_risk")
g.map(sns.histplot, "R_Claims_history", binwidth = 0.25, stat = 'percent')
g.set(xlim=(0, 6))
g.add_legend()

# %%
# cost/claim_year distribution by vehicle type

g = sns.FacetGrid(df, col="Type_risk", hue="Type_risk")
g.map(sns.histplot, "Cost/claim_year", binwidth = 0.5, stat = 'percent')
g.set(xlim=(0, 300))
g.add_legend()
# Out:
# Exception ignored in: <bound method IPythonKernel._clean_thread_parent_frames of <ipykernel.ipkernel.IPythonKernel object at 0x107b823b0>>
# Traceback (most recent call last):
#   File "/Users/mwilson/mambaforge/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 775, in _clean_thread_parent_frames
#     def _clean_thread_parent_frames(
# KeyboardInterrupt:
